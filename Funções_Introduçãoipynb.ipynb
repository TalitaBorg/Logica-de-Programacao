# %% [markdown]
# <a href="https://colab.research.google.com/github/TalitaBorg/Logica-de-Programacao/blob/main/Fun%C3%A7%C3%B5es_Introdu%C3%A7%C3%A3oipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def soma(numero1, numero2):
  s = numero1 + numero2
  print(s)
  return s

def subtracao(numero1, numero2):
  sub = numero1 - numero2
  print(sub)
  return sub

def media(numero1, numero2):
  media = (numero1 + numero2)/2
  print(media)
  return media

if __name__ == '__main__':
  #s = soma(1,2)
  #sub = subtracao(8,3)
  m = media(4,2)
# Out:
# 3.0
