# %% [markdown]
# <a href="https://colab.research.google.com/github/TalitaBorg/Logica-de-Programacao/blob/main/Contadores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
conta_par = 0
conta_impar = 0
contador = 0
while (contador < 10):
  numero = int(input("Digite um número: "))
  if(numero % 2 == 0):
    conta_par = conta_par + 1 #conta os números pares
  else:
    conta_impar = conta_impar + 1 #conta os números ímpares
  contador = contador + 1
print(f"Foram digitados {conta_par} números pares") #imprime na tela números pares
print(f"Foram digitados {conta_impar} números ímpares") #imprime na tela números ímpares
# Out:
# Digite um número: 2
# Digite um número: 8
# Digite um número: 9
# Digite um número: 3
# Digite um número: 4
# Digite um número: 7
# Digite um número: 6
# Digite um número: 7
# Digite um número: 8
# Digite um número: 2
# Foram digitados 6 números pares
# Foram digitados 4 números ímpares
