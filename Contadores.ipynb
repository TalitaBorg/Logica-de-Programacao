# %% [markdown]
# <a href="https://colab.research.google.com/github/TalitaBorg/Logica-de-Programacao/blob/main/Contadores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
conta_par = 0
conta_impar = 0
contador = 0
soma_par = 0

while (contador < 10):
  numero = int(input("Digite um número: "))
  if(numero % 2 == 0):
    conta_par = conta_par + 1 #conta os números pares
    soma_par = soma_par + numero
  else:
    conta_impar = conta_impar + 1 #conta os números ímpares
  contador = contador + 1
#print(f"Foram digitados {conta_par} números pares") #imprime na tela números pares
#print(f"Foram digitados {conta_impar} números ímpares") #imprime na tela números ímpares
print(f"Foram digitados {conta_par} números pares e a soma deles é {soma_par}")
if (conta_par > 0):
  media = (soma_par)/conta_par
  print(f"A média dos números pares é {media}")
# Out:
# Digite um número: 2
# Digite um número: 5
# Digite um número: 9
# Digite um número: 7
# Digite um número: 4
# Digite um número: 2
# Digite um número: 1
# Digite um número: 0
# Digite um número: 10
# Digite um número: 5
# Foram digitados 5 números pares
# Foram digitados 5 números ímpares
# Foram digitados 5 números pares e a soma deles é 18
# A média dos números pares é 3.6

# %%
conta_par = 0
conta_impar = 0
multiplica_par = 1
multiplica_impar = 1
contador = 0
quantidade = 5 #quantidade de nº que são lidos
while (contador < quantidade):
  numero = int(input("Digite um número: "))
  if (numero % 2 == 0):
    conta_par = conta_par + 1 #conta quantos nº pares o usuário digitou
    multiplica_par = multiplica_par * numero #multiplica valores pares
  else:
    conta_impar = conta_impar + 1 #conta quantos nº ímpares o usuário digitou
    multiplica_impar = multiplica_impar * numero #multiplica valores ímpares
  contador = contador + 1
  if (conta_par > 0):
    print(f"A multiplicação dos números pares é {multiplica_par}")
  else:
    print(f"Nenhum número par foi digitado!")
  if(conta_impar > 0):
    print(f"A multiplicação dos números ímpares é {multiplica_impar}")
  else:
    print(f"Nenhum número ímpar foi digitado!")
# Out:
# Digite um número: 2
# A multiplicação dos números pares é 2
# Nenhum número ímpar foi digitado!
# Digite um número: 5
# A multiplicação dos números pares é 2
# A multiplicação dos números ímpares é 5
# Digite um número: 6
# A multiplicação dos números pares é 12
# A multiplicação dos números ímpares é 5
# Digite um número: 8
# A multiplicação dos números pares é 96
# A multiplicação dos números ímpares é 5
# Digite um número: 9
# A multiplicação dos números pares é 96
# A multiplicação dos números ímpares é 45

# %%
numero = int(input("Digite um número: "))
contador = 0
while (contador <= 10):
  resultado = numero * contador
  print(f"{numero} * {contador} = {resultado}")
  contador = contador + 1
# Out:
# Digite um número: 2
# 2 * 0 = 0
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
# 2 * 10 = 20

# %%
contador = 0
soma = 0
while(contador < 10):
  numero = int(input("Digite um número: "))
  soma = soma + numero
  contador = contador + 1
print(f"A soma desses números é {soma}")
# Out:
# Digite um número: 5
# Digite um número: 5
# Digite um número: 5
# Digite um número: 5
# Digite um número: 5
# Digite um número: 5
# Digite um número: 5
# Digite um número: 5
# Digite um número: 5
# Digite um número: 5
# A soma desses números é 50

# %%
soma = 0
while True:
  numero = int(input("Digite um número a somar ou 0 para sair: "))
  if (numero == 0):
    break #condicao de parada
  else:
    soma = soma + numero
  print(f"O valor da soma é: {soma}")
# Out:
# Digite um número a somar ou 0 para sair: 4
# O valor da soma é: 4
# Digite um número a somar ou 0 para sair: 6
# O valor da soma é: 10
# Digite um número a somar ou 0 para sair: 0
