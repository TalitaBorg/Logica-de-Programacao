# %% [markdown]
# <a href="https://colab.research.google.com/github/TalitaBorg/Logica-de-Programacao/blob/main/Aula_20_03_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 1
b = 5
c = 2
d = 1

#Operadores Lógicos
a == b
b > a
a < b
a == d
d != a
c <= b
# Out:
# True

# %%
media = 7
aluno_Jorge = 8
aluna_Jaqueline = 6.5

aluno_Jorge >= media
#print("Aprovado!")

aluna_Jaqueline >= media
print("Reprovada!")
# Out:
# Reprovada!

# %%
a = True
b = False
c = True

#a and a
#b and b
#not c
#not b
#a and b
b or b
# Out:
# False

# %%
salario = float(input("Digite seu salário "))
salario > 1200
# Out:
# Digite seu salário 1234.54
# True
