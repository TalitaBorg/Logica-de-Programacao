# %% [markdown]
# <a href="https://colab.research.google.com/github/TalitaBorg/Logica-de-Programacao/blob/main/Programa1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Mostrar na tela a frase Olá Mundo!
print("Olá Mundo!")
# Out:
# Olá Mundo!

# %%
#soma
2+3

#subtracao
5-3

#adição e subtração
10-4+2

#Multiplicação
2*10

#divisão
20/4

#Exponenciação
2**10

#resto da divisão

10 % 3
# Out:
# 1

# %%
#soma
2+3
# Out:
# 5

# %%
#subtracao
5-3
# Out:
# 2

# %%
1500+(1500-5)/10
# Out:
# 1649.5

# %%
#Exercício 1
#a)
10+20*30
# Out:
# 610

# %%
10%3*10**2+1-10*4/2
# Out:
# 81.0
