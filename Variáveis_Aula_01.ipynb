# %% [markdown]
# <a href="https://colab.research.google.com/github/TalitaBorg/Logica-de-Programacao/blob/main/Vari%C3%A1veis_Aula_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#print("Frase")
a=2
b=3
#print(a+b)
soma = a+b
#print(soma)
multiplicacao = a*b
#print(multiplicacao)

exponenciacao = 2**3
print(exponenciacao)
# Out:
# 8

# %%
#Exercício 1
#Letra a) Faça um programa que exiba seu nome na tela
print("Talita Borges")
# Out:
# Talita Borges

# %%
a = 3
b= 5
v = 2*a*b
print(v)
# Out:
# 30

# %%
a = 2
b = 3
c = 4

soma = a+b+c
print(soma)
# Out:
# 9
